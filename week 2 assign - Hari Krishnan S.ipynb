# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# 1 Read the dataset to python environment.
# 2. Display the columns in the dataset.

file = pd.read_excel('iris.xls')
file
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# 3. Calculate the mean of each column of the dataset.

mean_list = list()
columns = file.columns[:-1]
for column in columns:
    mean_val = file[column].mean()
    mean_list.append(mean_val)

for (column, each) in zip(columns, mean_list):
    print('Mean of',column,'-',each)
# Out:
# Mean of SL - 5.843333333333335
# Mean of SW - 3.0540000000000007
# Mean of PL - 3.7586666666666693
# Mean of PW - 1.1986666666666672

# %%
# 4. Check for the null values present in the dataset.

0 in file.values
# Out:
# False

# %%
# 5 a) Visualization Number 1

sns.scatterplot(data = file, x ='SL', y = 'SW', hue = 'Classification' )
# Out:
# <AxesSubplot:xlabel='SL', ylabel='SW'>

# %%
# 5 b) visualization number 2

sns.scatterplot(data = file, x = 'PL', y = 'PW', hue = 'Classification')
# Out:
# <AxesSubplot:xlabel='PL', ylabel='PW'>

# %%
# 5 c) visualization number 3

sns.lineplot(data = file, x = 'SL', y = 'PL')
# Out:
# <AxesSubplot:xlabel='SL', ylabel='PL'>
